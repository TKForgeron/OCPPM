# %%
# Python native
import os

os.chdir('/'.join(os.getcwd().split('\\')[:-2]))
from typing import Any, Callable
import pickle
import re
import string
import pandas as pd
import numpy as np

# Object centric process mining
import ocpa.objects.log.importer.ocel.factory as ocel_import_factory
from ocpa.algo.predictive_monitoring.obj import Feature_Storage
from ocpa.objects.log.ocel import OCEL
import ocpa.algo.predictive_monitoring.factory as feature_factory
from ocpa.algo.predictive_monitoring import tabular
import ocpa.objects.log.importer.csv.factory as csv_import_factory

from sklearn.preprocessing import PowerTransformer, StandardScaler

# %%
feature_storage_out_file = "data/BPI17/feature_encodings/EFG/efg/raw/BPI_split_[C2_P2_P3_P5_O3_Action_EventOrigin_OrgResource].fs"
with open(feature_storage_out_file, "rb") as binary:
    fs: Feature_Storage = pickle.load(binary)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 feature_storage_out_file = "data/BPI17/feature_encodings/EFG/efg/raw/BPI_split_[C2_P2_P3_P5_O3_Action_EventOrigin_OrgResource].fs"
# ----> 2 with open(feature_storage_out_file, "rb") as binary:
#       3     fs: Feature_Storage = pickle.load(binary)
#
# File c:\Users\Tim\Development\OCPPM\.env\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/BPI17/feature_encodings/EFG/efg/raw/BPI_split_[C2_P2_P3_P5_O3_Action_EventOrigin_OrgResource].fs'

# %%
split_graphs = fs._get_train_test_split()

# %%
fs._event_id_table(split_graphs["test"]).iloc[:, ::-1].describe()
# Out:
#        event_OrgResource_ce  event_EventOrigin_ce  event_Action_ce  \
# count         117744.000000         117744.000000    117744.000000
# mean           12117.093270         132972.967005    165122.505189
# std            19687.426236          15020.636535     85111.899409
# min                9.000000         114852.000000     31509.000000
# 25%             2940.000000         114852.000000     86364.000000
# 50%             4298.000000         128226.000000    234196.000000
# 75%             6268.000000         150853.000000    234196.000000
# max            58953.000000         150853.000000    234196.000000
#
#        (event_previous_type_count, (offer,))  \
# count                          117744.000000
# mean                                1.039858
# std                                 0.884619
# min                                 0.000000
# 25%                                 1.000000
# 50%                                 1.000000
# 75%                                 1.000000
# max                                 8.000000
#
#        (event_synchronization_time, ())  (event_remaining_time, ())  \
# count                      1.177440e+05                1.177440e+05
# mean                       4.793677e+04                1.175018e+06
# std                        2.942438e+05                1.187782e+06
# min                        0.000000e+00                0.000000e+00
# 25%                        0.000000e+00                7.621872e+04
# 50%                        0.000000e+00                8.575724e+05
# 75%                        0.000000e+00                1.994145e+06
# max                        1.155350e+07                1.460426e+07
#
#        (event_elapsed_time, ())  \
# count              1.177440e+05
# mean               7.252024e+05
# std                1.026493e+06
# min                0.000000e+00
# 25%                1.124618e+03
# 50%                1.879031e+05
# 75%                1.105842e+06
# max                1.460426e+07
#
#        (event_preceding_activities, (Shorten completion,))  \
# count                                      117744.000000
# mean                                            0.000204
# std                                             0.014276
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        (event_preceding_activities, (Personal loan collection,))  \
# count                                      117744.000000
# mean                                            0.000008
# std                                             0.002914
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        (event_preceding_activities, (Assess potential fraud,))  ...  \
# count                                      117744.000000        ...
# mean                                            0.000722        ...
# std                                             0.026859        ...
# min                                             0.000000        ...
# 25%                                             0.000000        ...
# 50%                                             0.000000        ...
# 75%                                             0.000000        ...
# max                                             1.000000        ...
#
#        (event_preceding_activities, (Cancel offer,))  \
# count                                  117744.000000
# mean                                        0.018583
# std                                         0.138155
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         4.000000
#
#        (event_preceding_activities, (Call,))  \
# count                          117744.000000
# mean                                0.138351
# std                                 0.345294
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 2.000000
#
#        (event_preceding_activities, (Complete,))  \
# count                              117744.000000
# mean                                    0.076046
# std                                     0.265073
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        (event_preceding_activities, (Send (online),))  \
# count                                   117744.000000
# mean                                         0.005189
# std                                          0.073370
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          3.000000
#
#        (event_preceding_activities, (Create offer,))  \
# count                                  117744.000000
# mean                                        0.216257
# std                                         0.413135
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         2.000000
#
#        (event_preceding_activities, (Accept,))  \
# count                            117744.000000
# mean                                  0.080284
# std                                   0.271734
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        (event_preceding_activities, (Handle leads,))  \
# count                                  117744.000000
# mean                                        0.009062
# std                                         0.094763
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        (event_preceding_activities, (Submit,))  \
# count                            117744.000000
# mean                                  0.051688
# std                                   0.221398
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        (event_preceding_activities, (Create application,))       event_id
# count                                      117744.000000    117744.000000
# mean                                            0.080284    197717.939351
# std                                             0.271734    114112.567917
# min                                             0.000000        58.000000
# 25%                                             0.000000     99567.750000
# 50%                                             0.000000    196736.500000
# 75%                                             0.000000    296710.250000
# max                                             1.000000    393921.000000
#
# [8 rows x 29 columns]
