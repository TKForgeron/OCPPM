# %%
# Python native
import os

os.chdir("/home/tim/Development/OCPPM/")
from typing import Any, Callable
import pickle
import re
import string
import pandas as pd
import numpy as np

# Object centric process mining
import ocpa.objects.log.importer.ocel.factory as ocel_import_factory
from ocpa.algo.predictive_monitoring.obj import Feature_Storage
from ocpa.objects.log.ocel import OCEL
import ocpa.algo.predictive_monitoring.factory as feature_factory
from ocpa.algo.predictive_monitoring import tabular
import ocpa.objects.log.importer.csv.factory as csv_import_factory

from sklearn.preprocessing import PowerTransformer, StandardScaler

# %%
old_eft_file = "data/BPI17/feature_encodings/EFT/event_based_features.csv"
eft_out_file = "data/BPI17/feature_encodings/EFT/event_based_features_CountEncoded.csv"
feature_storage_out_file = "data/BPI17/feature_encodings/EFG/efg/raw/BPI_split_[C2_P2_P3_P5_O3_Action_EventOrigin_OrgResource].fs"

# %%
with open(feature_storage_out_file, "rb") as binary:
    feature_storage = pickle.load(binary)
eft = tabular.construct_table(feature_storage)
eft.shape
# Out:
# (393931, 28)

# %%
eft.columns.shape
# Out:
# (28,)

# %%
# Out:
# [('event_preceding_activities', ('Create application',)),
#  ('event_preceding_activities', ('Submit',)),
#  ('event_preceding_activities', ('Handle leads',)),
#  ('event_preceding_activities', ('Accept',)),
#  ('event_preceding_activities', ('Create offer',)),
#  ('event_preceding_activities', ('Send (online)',)),
#  ('event_preceding_activities', ('Complete',)),
#  ('event_preceding_activities', ('Call',)),
#  ('event_preceding_activities', ('Cancel offer',)),
#  ('event_preceding_activities', ('Send (mail and online)',)),
#  ('event_preceding_activities', ('Validate',)),
#  ('event_preceding_activities', ('Call incomplete files',)),
#  ('event_preceding_activities', ('Return',)),
#  ('event_preceding_activities', ('Cancel application',)),
#  ('event_preceding_activities', ('Accept offer',)),
#  ('event_preceding_activities', ('Pending',)),
#  ('event_preceding_activities', ('Deny',)),
#  ('event_preceding_activities', ('Refuse offer',)),
#  ('event_preceding_activities', ('Assess potential fraud',)),
#  ('event_preceding_activities', ('Personal loan collection',)),
#  ('event_preceding_activities', ('Shorten completion',)),
#  ('event_elapsed_time', ()),
#  ('event_remaining_time', ()),
#  ('event_synchronization_time', ()),
#  ('event_previous_type_count', ('offer',))]

# %%
scaler = StandardScaler()
eft_values = scaler.fit_transform(eft.values)
pd.DataFrame(eft_values, columns=eft.columns).head()
# Out:
#    (event_preceding_activities, (Create application,))  \
# 0                                          -0.294856
# 1                                          -0.294856
# 2                                          -0.294856
# 3                                          -0.294856
# 4                                          -0.294856
#
#    (event_preceding_activities, (Submit,))  \
# 0                                -0.233835
# 1                                -0.233835
# 2                                -0.233835
# 3                                -0.233835
# 4                                -0.233835
#
#    (event_preceding_activities, (Handle leads,))  \
# 0                                      -0.097731
# 1                                      -0.097731
# 2                                      -0.097731
# 3                                      -0.097731
# 4                                      -0.097731
#
#    (event_preceding_activities, (Accept,))  \
# 0                                -0.294856
# 1                                -0.294856
# 2                                -0.294856
# 3                                -0.294856
# 4                                -0.294856
#
#    (event_preceding_activities, (Create offer,))  \
# 0                                       1.893904
# 1                                       4.312149
# 2                                       1.893904
# 3                                      -0.524342
# 4                                      -0.524342
#
#    (event_preceding_activities, (Send (online),))  \
# 0                                       -0.069213
# 1                                       -0.069213
# 2                                       -0.069213
# 3                                       -0.069213
# 4                                       -0.069213
#
#    (event_preceding_activities, (Complete,))  \
# 0                                  -0.286365
# 1                                  -0.286365
# 2                                  -0.286365
# 3                                   3.492043
# 4                                  -0.286365
#
#    (event_preceding_activities, (Call,))  \
# 0                              -0.399320
# 1                              -0.399320
# 2                              -0.399320
# 3                              -0.399320
# 4                               2.503617
#
#    (event_preceding_activities, (Cancel offer,))  \
# 0                                      -0.134381
# 1                                      -0.134381
# 2                                      -0.134381
# 3                                      -0.134381
# 4                                      -0.134381
#
#    (event_preceding_activities, (Send (mail and online),))  ...  \
# 0                                          -0.328234        ...
# 1                                          -0.328234        ...
# 2                                          -0.328234        ...
# 3                                           2.931856        ...
# 4                                          -0.328234        ...
#
#    (event_preceding_activities, (Assess potential fraud,))  \
# 0                                          -0.025798
# 1                                          -0.025798
# 2                                          -0.025798
# 3                                          -0.025798
# 4                                          -0.025798
#
#    (event_preceding_activities, (Personal loan collection,))  \
# 0                                           -0.00276
# 1                                           -0.00276
# 2                                           -0.00276
# 3                                           -0.00276
# 4                                           -0.00276
#
#    (event_preceding_activities, (Shorten completion,))  \
# 0                                          -0.013799
# 1                                          -0.013799
# 2                                          -0.013799
# 3                                          -0.013799
# 4                                          -0.013799
#
#    (event_elapsed_time, ())  (event_remaining_time, ())  \
# 0                 -0.705739                    8.671991
# 1                 -0.705730                    8.671984
# 2                 -0.705706                    8.671963
# 3                 -0.705706                    8.671963
# 4                  1.375277                    6.872730
#
#    (event_synchronization_time, ())  (event_previous_type_count, (offer,))  \
# 0                         -0.163154                               1.059050
# 1                         -0.162797                               1.059050
# 2                         -0.163154                               1.059050
# 3                         -0.163154                               1.059050
# 4                         -0.163154                               2.171154
#
#    event_Action_ce  event_EventOrigin_ce  event_OrgResource_ce
# 0         0.811704              1.189447             -0.397887
# 1         0.811704              1.189447             -0.397887
# 2         0.811704              1.189447             -0.397887
# 3        -0.925827             -0.317357             -0.397887
# 4         0.811704              1.189447             -0.317180
#
# [5 rows x 28 columns]
